# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Loading the data set
training = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
training

# %%
#traing.info() gives the null count and the data types of the columns
training.info()

# %%
#Gives the details of various parameters on data
training.describe()

# %%
#separating numeric and categorical data for visualization
df_num = training[['Age', 'SibSp', 'Parch', 'Fare']]
df_cat = training[['Survived', 'Pclass', 'Sex', 'Ticket', 'Cabin', 'Embarked']]

# %%
for i in df_num:
    plt.hist(df_num[i])
    plt.title(i)
    plt.show()

# %%
df_num.corr()
sns.heatmap(df_num.corr())
# Out:
# <Axes: >

# %%
print(df_num.corr(['survived']))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_6879/1736185357.py in ?()
# ----> 1 df_num.corr(['survived'])
#
# ~/.local/lib/python3.12/site-packages/pandas/core/frame.py in ?(self, method, min_periods, numeric_only)
#   11076                         c = corrf(ac, bc)
#   11077                     correl[i, j] = c
#   11078                     correl[j, i] = c
#   11079         else:
# > 11080             raise ValueError(
#   11081                 "method must be either 'pearson', "
#   11082                 "'spearman', 'kendall', or a callable, "
#   11083                 f"'{method}' was supplied"
#
# ValueError: method must be either 'pearson', 'spearman', 'kendall', or a callable, '['survived']' was supplied
